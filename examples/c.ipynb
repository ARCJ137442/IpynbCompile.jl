// %% [markdown]
// # Jupyter样例 @ C（尚不完整）

// %% [markdown]
// ✨Powered by [***Jupyter-C-Kernel***](https://github.com/brendan-rius/jupyter-c-kernel)

// %% [markdown]
// 内核配置文件: `C:\ProgramData\jupyter\kernels\c\kernel.json`

// %%
#include <stdio.h>
int main()
{
    printf("Hello Jupyter!");
    return 0;
}
